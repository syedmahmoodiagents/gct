# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import make_regression, load_iris

# %% [markdown]
# # Using load_based dataset

# %%
load_iris().keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
dt = load_iris()

# %%
dt.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
df = pd.DataFrame(dt.data, columns=dt.feature_names)

# %%
df.rename(columns={'sepal length (cm)':'sepal_length', 'sepal width (cm)':'sepal_width', 'petal length (cm)':'petal_length', 'petal width (cm)':'petal_width'}, inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
df['target'] = dt.target

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
df[df['sepal_length']>5]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0             5.1          3.5           1.4          0.2       0
# 5             5.4          3.9           1.7          0.4       0
# 10            5.4          3.7           1.5          0.2       0
# 14            5.8          4.0           1.2          0.2       0
# 15            5.7          4.4           1.5          0.4       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [118 rows x 5 columns]

# %%
df.loc[df['sepal_length']>5, ['sepal_length', 'sepal_width']]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 5             5.4          3.9
# 10            5.4          3.7
# 14            5.8          4.0
# 15            5.7          4.4
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [118 rows x 2 columns]

# %%
df.loc[df['sepal_length']< 6, 'new_column'] = 'small sepals'

# %%
df.loc[df['sepal_length']>= 6, 'new_column'] = 'big sepals'

# %%
df['updated_column'] = df['sepal_length'].apply(lambda x: 'smaller sepals' if x < 6 else 'large sepals')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target  \
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
#        new_column  updated_column
# 0    small sepals  smaller sepals
# 1    small sepals  smaller sepals
# 2    small sepals  smaller sepals
# 3    small sepals  smaller sepals
# 4    small sepals  smaller sepals
# ..            ...             ...
# 145    big sepals    large sepals
# 146    big sepals    large sepals
# 147    big sepals    large sepals
# 148    big sepals    large sepals
# 149  small sepals  smaller sepals
#
# [150 rows x 7 columns]

# %% [markdown]
# # Using Make_based dataset

# %%
x,y = make_regression(n_samples=20, n_features=4, bias=10.3, noise=1.8)

# %%
x.shape
# Out:
# (20, 4)

# %%
y.shape
# Out:
# (20,)

# %%
df = pd.DataFrame(x).round(2)

# %%
df
# Out:
#        0     1     2     3
# 0   0.73 -1.18 -0.46 -0.47
# 1   0.47  0.09  0.38  0.44
# 2  -0.81  1.89  1.05 -1.27
# 3   0.11 -1.26  0.63  0.82
# 4   0.46 -0.48  1.31 -0.53
# 5  -0.35 -0.06 -0.19  0.12
# 6  -1.40  1.04  1.39  0.92
# 7  -1.52  0.25 -0.41 -1.35
# 8  -1.49 -0.09  0.65  0.32
# 9   0.20  0.95 -0.08 -0.05
# 10 -0.88 -0.58  0.84 -0.14
# 11 -0.14 -0.15  0.87 -1.10
# 12 -1.36 -0.67 -1.57 -1.76
# 13 -0.18 -0.10 -0.01 -0.19
# 14 -2.03 -0.43  2.57  0.90
# 15 -1.29  0.58 -0.43  0.15
# 16  0.91 -1.03  0.04  0.22
# 17 -0.18  0.90  0.25  1.12
# 18 -1.25  1.87 -0.03  0.26
# 19  1.24 -0.36  0.43 -0.01

# %%
df.columns = ["col1", "col2", "col3", "col4"]

# %%
df.rename()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_654/3351268036.py in <cell line: 0>()
# ----> 1 df.rename()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5765         4  3  6
#    5766         """
# -> 5767         return super()._rename(
#    5768             mapper=mapper,
#    5769             index=index,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1084
#    1085         if mapper is None and index is None and columns is None:
# -> 1086             raise TypeError("must pass an index to rename")
#    1087
#    1088         if index is not None or columns is not None:
#
# TypeError: must pass an index to rename

# %%
df
# Out:
#     col1  col2  col3  col4
# 0   0.73 -1.18 -0.46 -0.47
# 1   0.47  0.09  0.38  0.44
# 2  -0.81  1.89  1.05 -1.27
# 3   0.11 -1.26  0.63  0.82
# 4   0.46 -0.48  1.31 -0.53
# 5  -0.35 -0.06 -0.19  0.12
# 6  -1.40  1.04  1.39  0.92
# 7  -1.52  0.25 -0.41 -1.35
# 8  -1.49 -0.09  0.65  0.32
# 9   0.20  0.95 -0.08 -0.05
# 10 -0.88 -0.58  0.84 -0.14
# 11 -0.14 -0.15  0.87 -1.10
# 12 -1.36 -0.67 -1.57 -1.76
# 13 -0.18 -0.10 -0.01 -0.19
# 14 -2.03 -0.43  2.57  0.90
# 15 -1.29  0.58 -0.43  0.15
# 16  0.91 -1.03  0.04  0.22
# 17 -0.18  0.90  0.25  1.12
# 18 -1.25  1.87 -0.03  0.26
# 19  1.24 -0.36  0.43 -0.01

# %%
df.rename(columns={
    "col1":"delhi",
    "col2":"mumbai",
    "col3":"bengluru",
    "col4":"chennai"
}, inplace=True)

# %%
df
# Out:
#     delhi  mumbai  bengluru  chennai
# 0    0.73   -1.18     -0.46    -0.47
# 1    0.47    0.09      0.38     0.44
# 2   -0.81    1.89      1.05    -1.27
# 3    0.11   -1.26      0.63     0.82
# 4    0.46   -0.48      1.31    -0.53
# 5   -0.35   -0.06     -0.19     0.12
# 6   -1.40    1.04      1.39     0.92
# 7   -1.52    0.25     -0.41    -1.35
# 8   -1.49   -0.09      0.65     0.32
# 9    0.20    0.95     -0.08    -0.05
# 10  -0.88   -0.58      0.84    -0.14
# 11  -0.14   -0.15      0.87    -1.10
# 12  -1.36   -0.67     -1.57    -1.76
# 13  -0.18   -0.10     -0.01    -0.19
# 14  -2.03   -0.43      2.57     0.90
# 15  -1.29    0.58     -0.43     0.15
# 16   0.91   -1.03      0.04     0.22
# 17  -0.18    0.90      0.25     1.12
# 18  -1.25    1.87     -0.03     0.26
# 19   1.24   -0.36      0.43    -0.01

# %%
pd.date_range("2026-07-05", periods=20, freq="W")
# Out:
# DatetimeIndex(['2026-07-05', '2026-07-12', '2026-07-19', '2026-07-26',
#                '2026-08-02', '2026-08-09', '2026-08-16', '2026-08-23',
#                '2026-08-30', '2026-09-06', '2026-09-13', '2026-09-20',
#                '2026-09-27', '2026-10-04', '2026-10-11', '2026-10-18',
#                '2026-10-25', '2026-11-01', '2026-11-08', '2026-11-15'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
df.set_index(pd.date_range("2026-07-05", periods=20, freq="W"), inplace=True)

# %%
df
# Out:
#             delhi  mumbai  bengluru  chennai
# 2026-07-05   0.73   -1.18     -0.46    -0.47
# 2026-07-12   0.47    0.09      0.38     0.44
# 2026-07-19  -0.81    1.89      1.05    -1.27
# 2026-07-26   0.11   -1.26      0.63     0.82
# 2026-08-02   0.46   -0.48      1.31    -0.53
# 2026-08-09  -0.35   -0.06     -0.19     0.12
# 2026-08-16  -1.40    1.04      1.39     0.92
# 2026-08-23  -1.52    0.25     -0.41    -1.35
# 2026-08-30  -1.49   -0.09      0.65     0.32
# 2026-09-06   0.20    0.95     -0.08    -0.05
# 2026-09-13  -0.88   -0.58      0.84    -0.14
# 2026-09-20  -0.14   -0.15      0.87    -1.10
# 2026-09-27  -1.36   -0.67     -1.57    -1.76
# 2026-10-04  -0.18   -0.10     -0.01    -0.19
# 2026-10-11  -2.03   -0.43      2.57     0.90
# 2026-10-18  -1.29    0.58     -0.43     0.15
# 2026-10-25   0.91   -1.03      0.04     0.22
# 2026-11-01  -0.18    0.90      0.25     1.12
# 2026-11-08  -1.25    1.87     -0.03     0.26
# 2026-11-15   1.24   -0.36      0.43    -0.01

# %%
df.to_excel("regression.xlsx")

# %%
ndf = pd.read_excel("regression.xlsx", index_col="Unnamed: 0")

# %%
ndf
# Out:
#             delhi  mumbai  bengluru  chennai
# 2026-07-05   0.73   -1.18     -0.46    -0.47
# 2026-07-12   0.47    0.09      0.38     0.44
# 2026-07-19  -0.81    1.89      1.05    -1.27
# 2026-07-26   0.11   -1.26      0.63     0.82
# 2026-08-02   0.46   -0.48      1.31    -0.53
# 2026-08-09  -0.35   -0.06     -0.19     0.12
# 2026-08-16  -1.40    1.04      1.39     0.92
# 2026-08-23  -1.52    0.25     -0.41    -1.35
# 2026-08-30  -1.49   -0.09      0.65     0.32
# 2026-09-06   0.20    0.95     -0.08    -0.05
# 2026-09-13  -0.88   -0.58      0.84    -0.14
# 2026-09-20  -0.14   -0.15      0.87    -1.10
# 2026-09-27  -1.36   -0.67     -1.57    -1.76
# 2026-10-04  -0.18   -0.10     -0.01    -0.19
# 2026-10-11  -2.03   -0.43      2.57     0.90
# 2026-10-18  -1.29    0.58     -0.43     0.15
# 2026-10-25   0.91   -1.03      0.04     0.22
# 2026-11-01  -0.18    0.90      0.25     1.12
# 2026-11-08  -1.25    1.87     -0.03     0.26
# 2026-11-15   1.24   -0.36      0.43    -0.01

# %%
ndf.loc[:,'delhi']
# Out:
# 2026-07-05    0.73
# 2026-07-12    0.47
# 2026-07-19   -0.81
# 2026-07-26    0.11
# 2026-08-02    0.46
# 2026-08-09   -0.35
# 2026-08-16   -1.40
# 2026-08-23   -1.52
# 2026-08-30   -1.49
# 2026-09-06    0.20
# 2026-09-13   -0.88
# 2026-09-20   -0.14
# 2026-09-27   -1.36
# 2026-10-04   -0.18
# 2026-10-11   -2.03
# 2026-10-18   -1.29
# 2026-10-25    0.91
# 2026-11-01   -0.18
# 2026-11-08   -1.25
# 2026-11-15    1.24
# Name: delhi, dtype: float64

# %%
ndf[(ndf["delhi"] > 0) & (ndf['mumbai'] > 0)]
# Out:
#             delhi  mumbai  bengluru  chennai
# 2026-07-12   0.47    0.09      0.38     0.44
# 2026-09-06   0.20    0.95     -0.08    -0.05

# %%
ndf.loc[ndf["delhi"] > 0, ["delhi", "mumbai"]]
# Out:
#             delhi  mumbai
# 2026-07-05   0.73   -1.18
# 2026-07-12   0.47    0.09
# 2026-07-26   0.11   -1.26
# 2026-08-02   0.46   -0.48
# 2026-09-06   0.20    0.95
# 2026-10-25   0.91   -1.03
# 2026-11-15   1.24   -0.36

# %%
# ndf.loc[ndf["delhi"] > 0, ]
