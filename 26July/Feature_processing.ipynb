# %%
import numpy as np
import pandas as pd

# %%
pd.read_excel('feturesj.xlsx', index_col="")
# Out:
#      Unnamed: 0  sepal_len  sepal_wid  petal_len  petal_wid     target
# 0             0        5.1        3.5        1.4        0.2     setosa
# 1             1        4.9        3.0        1.4        0.2     setosa
# 2             2        4.7        3.2        1.3        0.2     setosa
# 3             3        4.6        3.1        1.5        0.2     setosa
# 4             4        5.0        3.6        1.4        0.2     setosa
# ..          ...        ...        ...        ...        ...        ...
# 145         145        6.7        3.0        5.2        2.3  virginica
# 146         146        6.3        2.5        5.0        1.9  virginica
# 147         147        6.5        3.0        5.2        2.0  virginica
# 148         148        6.2        3.4        5.4        2.3  virginica
# 149         149        5.9        3.0        5.1        1.8  virginica
#
# [150 rows x 6 columns]

# %%
df = pd.read_excel('feturesj.xlsx', index_col="Unnamed: 0")

# %%
df.describe(include='all')
# Out:
#          sepal_len   sepal_wid   petal_len   petal_wid  target
# count   150.000000  150.000000  150.000000  150.000000     150
# unique         NaN         NaN         NaN         NaN       3
# top            NaN         NaN         NaN         NaN  setosa
# freq           NaN         NaN         NaN         NaN      50
# mean      5.843333    3.057333    3.758000    1.199333     NaN
# std       0.828066    0.435866    1.765298    0.762238     NaN
# min       4.300000    2.000000    1.000000    0.100000     NaN
# 25%       5.100000    2.800000    1.600000    0.300000     NaN
# 50%       5.800000    3.000000    4.350000    1.300000     NaN
# 75%       6.400000    3.300000    5.100000    1.800000     NaN
# max       7.900000    4.400000    6.900000    2.500000     NaN

# %%
df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df['sepal_wid'].plot.box()
# Out:
# <Axes: >

# %%
df['sepal_wid'].min()
# Out:
# 2.0

# %%
df['sepal_wid'].max()
# Out:
# 4.4

# %%
df['sepal_wid'].mean()
# Out:
# np.float64(3.0573333333333337)

# %%
df.loc[(df['sepal_wid'] == 2), 'sepal_wid'] = df['sepal_wid'].mean()

# %%
df['sepal_wid']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_wid, Length: 150, dtype: float64

# %%
df['sepal_wid'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.loc[(df['sepal_wid'] == df['sepal_wid'].max()), 'sepal_wid'] = df['sepal_wid'].mean()

# %%
df.loc[(df['sepal_wid'] == df['sepal_wid'].max()), 'sepal_wid'] = df['sepal_wid'].mean()

# %%
df.loc[(df['sepal_wid'] == df['sepal_wid'].max()), 'sepal_wid'] = df['sepal_wid'].mean()

# %%
df['sepal_wid'].plot(kind='box')
# Out:
# <Axes: >
